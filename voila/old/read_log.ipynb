# %%
import pandas as pd
pd.set_option('display.max_rows', None)
df = pd.read_csv('logbook.csv') 
df
# Out:
#        Files  PhotonEnergy(eV) Polarization  Temperature(K)  SampleX(mm)  \
# 0    Co_0001           778.000           LV           19.80       0.0003
# 1    Co_0002           777.999           LV           19.71       0.0004
# 2    Co_0003           778.002           LV           19.43       0.0004
# 3    Co_0004           778.000           LV           19.53       0.0004
# 4    Co_0005           778.003           LV           19.71       0.0004
# 5    Co_0006           778.000           LV           19.73       0.0004
# 6    Co_0007           773.998           LV           19.71       0.0004
# 7    Co_0008           774.997           LV           19.64       0.0004
# 8    Co_0009           775.999           LV           19.65       0.0004
# 9    Co_0010           776.997           LV           19.65       0.0004
# 10   Co_0011           778.001           LV           19.62       0.0004
# 11   Co_0012           778.999           LV           19.82       0.0004
# ...
