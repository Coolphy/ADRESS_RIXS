# %%
# %matplotlib widget
import matplotlib.pyplot as plt

from adress_rixs import adress_rixs

# %%
ar = adress_rixs(
    path=r"X:/RIXS/Asmara", 
    base="O", 
    dispersion=0.00457,
    )

# %%
x,y = ar.load_rixs(16,17,18,19,20)

plt.figure()
plt.plot(x,y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
